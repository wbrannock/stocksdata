# %%
import pandas as pd
import numpy as np

# %%
# Load the stocks file
stocks = pd.read_csv('archive/sp500_stocks.csv')
stocks.describe()
# Out:
#            Adj Close          Close           High            Low  \
# count  617831.000000  617831.000000  617831.000000  617831.000000
# mean       79.672357      87.471540      88.417844      86.480997
# std       102.742931     104.521901     105.684113     103.300770
# min         0.203593       0.222000       0.226250       0.216250
# 25%        26.572459      32.700001      33.060001      32.299999
# 50%        49.821613      59.139999      59.720001      58.500000
# 75%        94.831036     105.019997     106.129997     103.889999
# max      1702.530029    1702.530029    1714.750000    1696.900024
#
#                 Open        Volume
# count  617831.000000  6.178310e+05
# mean       87.460302  9.347125e+06
# std       104.519845  4.771669e+07
# min         0.218000  0.000000e+00
# 25%        32.689999  1.144000e+06
# 50%        59.119999  2.453400e+06
# 75%       105.000000  5.657850e+06
# max      1706.400024  3.692928e+09

# %%
# Missing Analysis
missing_data = stocks.isnull().sum()
print("Missing Data per Column:")
print(missing_data)
# Out:
# Missing Data per Column:
# Date               0
# Symbol             0
# Adj Close    1273705
# Close        1273705
# High         1273705
# Low          1273705
# Open         1273705
# Volume       1273705
# dtype: int64

# %%
# Check Missing Data By Year
stocks['Year'] = pd.to_datetime(stocks['Date']).dt.year
missing_by_year = stocks.groupby('Year').apply(lambda x: x.isnull().sum())
missing_by_year
# Out:
# /var/folders/2n/rqnjq39x0bl3l55y0ghnzcz00000gn/T/ipykernel_45970/3536166782.py:3: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   missing_by_year = stocks.groupby('Year').apply(lambda x: x.isnull().sum())
#       Date  Symbol  Adj Close  Close   High    Low   Open  Volume  Year
# Year
# 2010     0       0      88574  88574  88574  88574  88574   88574     0
# 2011     0       0      87993  87993  87993  87993  87993   87993     0
# 2012     0       0      86656  86656  86656  86656  86656   86656     0
# 2013     0       0      86733  86733  86733  86733  86733   86733     0
# 2014     0       0      85932  85932  85932  85932  85932   85932     0
# 2015     0       0      85436  85436  85436  85436  85436   85436     0
# 2016     0       0      85081  85081  85081  85081  85081   85081     0
# 2017     0       0      84195  84195  84195  84195  84195   84195     0
# 2018     0       0      84085  84085  84085  84085  84085   84085     0
# 2019     0       0      83848  83848  83848  83848  83848   83848     0
# 2020     0       0      83996  83996  83996  83996  83996   83996     0
# 2021     0       0      83664  83664  83664  83664  83664   83664     0
# 2022     0       0      83332  83332  83332  83332  83332   83332     0
# 2023     0       0      82939  82939  82939  82939  82939   82939     0
# 2024     0       0      81241  81241  81241  81241  81241   81241     0

# %%
# Check Missing Data by Company
missing_by_company = stocks.groupby('Symbol').apply(lambda x: x.isnull().sum())
missing_by_company
# Out:
# /var/folders/2n/rqnjq39x0bl3l55y0ghnzcz00000gn/T/ipykernel_45970/1650259912.py:2: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   missing_by_company = stocks.groupby('Symbol').apply(lambda x: x.isnull().sum())
#         Date  Symbol  Adj Close  Close  High   Low  Open  Volume  Year
# Symbol
# A          0       0       3768   3768  3768  3768  3768    3768     0
# AAPL       0       0       3768   3768  3768  3768  3768    3768     0
# ABBV       0       0        754    754   754   754   754     754     0
# ABNB       0       0       3768   3768  3768  3768  3768    3768     0
# ABT        0       0          0      0     0     0     0       0     0
# ...      ...     ...        ...    ...   ...   ...   ...     ...   ...
# XYL        0       0        449    449   449   449   449     449     0
# YUM        0       0       3768   3768  3768  3768  3768    3768     0
# ZBH        0       0       3768   3768  3768  3768  3768    3768     0
# ZBRA       0       0       3768   3768  3768  3768  3768    3768     0
# ZTS        0       0       3768   3768  3768  3768  3768    3768     0
#
# [502 rows x 9 columns]

# %%
# How many companies are not fully missing for all years
partially_missing = missing_by_company[(missing_by_company[['Adj Close', 'Open', 'High', 'Low', 'Close', 'Volume']] < len(stocks['Date'].unique())).any(axis=1)]

# Filter out data where any of the columns are greater than zero
partially_missing = partially_missing.query('Low > 0 or High > 0 or Open > 0 or Close > 0 or Volume > 0 or `Adj Close` > 0')
partially_missing

#
# Out:
#         Date  Symbol  Adj Close  Close  High   Low  Open  Volume  Year
# Symbol
# ABBV       0       0        754    754   754   754   754     754     0
# ALLE       0       0        976    976   976   976   976     976     0
# ANET       0       0       1113   1113  1113  1113  1113    1113     0
# DELL       0       0       1667   1667  1667  1667  1667    1667     0
# ENPH       0       0        565    565   565   565   565     565     0
# FOX        0       0       2312   2312  2312  2312  2312    2312     0
# FOXA       0       0       2311   2311  2311  2311  2311    2311     0
# GDDY       0       0       1318   1318  1318  1318  1318    1318     0
# HCA        0       0        298    298   298   298   298     298     0
# HII        0       0        306    306   306   306   306     306     0
# HLT        0       0        993    993   993   993   993     993     0
# HPE        0       0       1458   1458  1458  1458  1458    1458     0
# INVH       0       0       1782   1782  1782  1782  1782    1782     0
# IQV        0       0        842    842   842   842   842     842     0
# IR         0       0       1852   1852  1852  1852  1852    1852     0
# META       0       0        599    599   599   599   599     599     0
# SOLV       0       0       3583   3583  3583  3583  3583    3583     0
# SYF        0       0       1151   1151  1151  1151  1151    1151     0
# TSLA       0       0        122    122   122   122   122     122     0
# UBER       0       0       2353   2353  2353  2353  2353    2353     0
# VLTO       0       0       3461   3461  3461  3461  3461    3461     0
# XYL        0       0        449    449   449   449   449     449     0

# %%
# Look at AMD for 2023
amd_2023 = stocks[(stocks['Symbol'] == 'AMD') & (stocks['Year'] == 2023)]
amd_2023
# Out:
#              Date Symbol  Adj Close  Close  High  Low  Open  Volume  Year
# 25880  2023-01-03    AMD        NaN    NaN   NaN  NaN   NaN     NaN  2023
# 25881  2023-01-04    AMD        NaN    NaN   NaN  NaN   NaN     NaN  2023
# 25882  2023-01-05    AMD        NaN    NaN   NaN  NaN   NaN     NaN  2023
# 25883  2023-01-06    AMD        NaN    NaN   NaN  NaN   NaN     NaN  2023
# 25884  2023-01-09    AMD        NaN    NaN   NaN  NaN   NaN     NaN  2023
# ...           ...    ...        ...    ...   ...  ...   ...     ...   ...
# 26125  2023-12-22    AMD        NaN    NaN   NaN  NaN   NaN     NaN  2023
# 26126  2023-12-26    AMD        NaN    NaN   NaN  NaN   NaN     NaN  2023
# 26127  2023-12-27    AMD        NaN    NaN   NaN  NaN   NaN     NaN  2023
# 26128  2023-12-28    AMD        NaN    NaN   NaN  NaN   NaN     NaN  2023
# 26129  2023-12-29    AMD        NaN    NaN   NaN  NaN   NaN     NaN  2023
#
# [250 rows x 9 columns]

# %%
# Filter companies with all missing numeric columns
num_cols = ['Adj Close', 'Open', 'High', 'Low', 'Close', 'Volume']
companies_all_missing = stocks.groupby('Symbol').filter(
    lambda x: x[num_cols].isnull().all().all()
)['Symbol'].unique()
companies_all_missing
# Out:
# array(['MMM', 'ACN', 'ADBE', 'AMD', 'AFL', 'A', 'APD', 'ABNB', 'AKAM',
#        'ARE', 'ALGN', 'LNT', 'GOOGL', 'AMCR', 'AMTM', 'AEE', 'AEP', 'AIG',
#        'AMT', 'AWK', 'AME', 'AMGN', 'ADI', 'AON', 'APA', 'AAPL', 'AMAT',
#        'APTV', 'ACGL', 'AIZ', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY',
#        'BALL', 'BAC', 'BRK-B', 'TECH', 'BIIB', 'BLK', 'BX', 'BA', 'BKNG',
#        'BMY', 'AVGO', 'BR', 'BF-B', 'BG', 'BXP', 'CHRW', 'CDNS', 'CZR',
#        'CPT', 'CPB', 'CAH', 'CARR', 'CBOE', 'CBRE', 'CDW', 'COR', 'CNC',
#        'CNP', 'CF', 'CRL', 'SCHW', 'CHTR', 'CMG', 'CB', 'CHD', 'CI',
#        'CINF', 'CTAS', 'CFG', 'CMS', 'KO', 'CTSH', 'CL', 'CAG', 'COP',
#        'CEG', 'COO', 'CPRT', 'CPAY', 'CTVA', 'COST', 'CTRA', 'CRWD',
#        'CCI', 'CSX', 'CMI', 'CVS', 'DHR', 'DRI', 'DVA', 'DAY', 'DECK',
#        'DAL', 'DVN', 'FANG', 'DLTR', 'D', 'DOW', 'DUK', 'DD', 'ETN',
#        'EBAY', 'ECL', 'EW', 'ELV', 'EMR', 'ETR', 'EOG', 'EPAM', 'ERIE',
#        'EG', 'EVRG', 'ES', 'EXC', 'EXPD', 'EXR', 'XOM', 'FICO', 'FIS',
#        'FITB', 'FE', 'FI', 'FMC', 'F', 'FTV', 'GRMN', 'IT', 'GE', 'GEHC',
#        'GEV', 'GEN', 'GNRC', 'GD', 'GM', 'GPC', 'GILD', 'GL', 'GS', 'HAL',
#        'HAS', 'DOC', 'HSY', 'HES', 'HOLX', 'HD', 'HON', 'HWM', 'HPQ',
#        'HUBB', 'HUM', 'HBAN', 'IBM', 'IDXX', 'ITW', 'INTC', 'IPG', 'INTU',
#        'IVZ', 'JBL', 'JKHY', 'J', 'JNJ', 'JPM', 'JNPR', 'KVUE', 'KDP',
#        'KEY', 'KEYS', 'KMB', 'KMI', 'KKR', 'KLAC', 'KHC', 'KR', 'LHX',
#        'LW', 'LVS', 'LDOS', 'LLY', 'LIN', 'LYV', 'LMT', 'L', 'LOW',
#        'LULU', 'LYB', 'MTB', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS',
#        'MA', 'MTCH', 'MKC', 'MCK', 'MDT', 'MET', 'MGM', 'MCHP', 'MU',
#        'MAA', 'MRNA', 'MHK', 'MOH', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO',
#        'MS', 'MOS', 'MSCI', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI',
#        'NDSN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVR', 'NXPI',
#        'ORLY', 'OXY', 'ODFL', 'OKE', 'OTIS', 'PCAR', 'PLTR', 'PANW',
#        'PAYC', 'PYPL', 'PNR', 'PFE', 'PCG', 'PSX', 'POOL', 'PG', 'PLD',
#        'PRU', 'PTC', 'PSA', 'QRVO', 'QCOM', 'DGX', 'RL', 'REG', 'REGN',
#        'RSG', 'RMD', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'SBAC',
#        'SLB', 'STX', 'SRE', 'NOW', 'SPG', 'SWKS', 'SJM', 'SW', 'SNA',
#        'LUV', 'STT', 'STLD', 'STE', 'SYK', 'SMCI', 'SNPS', 'SYY', 'TMUS',
#        'TROW', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TXN',
#        'TPL', 'TXT', 'TMO', 'TSCO', 'TRV', 'TRMB', 'TFC', 'TYL', 'ULTA',
#        'UNP', 'URI', 'UNH', 'VTR', 'VRSN', 'VZ', 'VICI', 'VST', 'VMC',
#        'GWW', 'WAB', 'WBA', 'WMT', 'WBD', 'WM', 'WAT', 'WFC', 'WY',
#        'WYNN', 'XEL', 'YUM', 'ZBRA', 'ZBH', 'ZTS'], dtype=object)

# %%
# Create new dataframe to join with company metadata
missing_companies = pd.DataFrame(companies_all_missing, columns=['Symbol'])
missing_companies

# Merge with metadata
company_metadata = pd.read_csv('archive/sp500_companies.csv')
merged_data = pd.merge(company_metadata, missing_companies, on='Symbol', how='left', indicator='matched')
merged_data
# Out:
#     Exchange Symbol                    Shortname                     Longname  \
# 0        NMS   AAPL                   Apple Inc.                   Apple Inc.
# 1        NMS   NVDA           NVIDIA Corporation           NVIDIA Corporation
# 2        NMS   MSFT        Microsoft Corporation        Microsoft Corporation
# 3        NMS   AMZN             Amazon.com, Inc.             Amazon.com, Inc.
# 4        NMS  GOOGL                Alphabet Inc.                Alphabet Inc.
# ..       ...    ...                          ...                          ...
# 497      NMS    CZR  Caesars Entertainment, Inc.  Caesars Entertainment, Inc.
# 498      NYQ    BWA              BorgWarner Inc.              BorgWarner Inc.
# 499      NMS   QRVO                  Qorvo, Inc.                  Qorvo, Inc.
# 500      NYQ    FMC              FMC Corporation              FMC Corporation
# 501      NYQ   AMTM       Amentum Holdings, Inc.       Amentum Holdings, Inc.
#
#                      Sector                        Industry  Currentprice  \
# 0                Technology            Consumer Electronics        254.49
# 1                Technology                  Semiconductors        134.70
# 2                Technology       Software - Infrastructure        436.60
# 3         Consumer Cyclical                 Internet Retail        224.92
# 4    Communication Services  Internet Content & Information        191.41
# ..                      ...                             ...           ...
# 497       Consumer Cyclical               Resorts & Casinos         32.82
# 498       Consumer Cyclical                      Auto Parts         31.88
# 499              Technology                  Semiconductors         70.85
# 500         Basic Materials             Agricultural Inputs         50.15
# 501             Industrials     Specialty Business Services         19.17
#
#          Marketcap        Ebitda  Revenuegrowth           City State  \
# 0    3846819807232  1.346610e+11          0.061      Cupertino    CA
# 1    3298803056640  6.118400e+10          1.224    Santa Clara    CA
# 2    3246068596736  1.365520e+11          0.160        Redmond    WA
# 3    2365033807872  1.115830e+11          0.110        Seattle    WA
# 4    2351625142272  1.234700e+11          0.151  Mountain View    CA
# ..             ...           ...            ...            ...   ...
# 497     6973593600  3.668000e+09         -0.040           Reno    NV
# 498     6972155904  1.882000e+09         -0.048   Auburn Hills    MI
# 499     6697217024  6.731300e+08         -0.052     Greensboro    NC
# 500     6260525568  7.033000e+08          0.085   Philadelphia    PA
# 501     4664099328  4.330000e+08         -0.031      Chantilly    VA
#
#            Country  Fulltimeemployees  \
# 0    United States           164000.0
# 1    United States            29600.0
# 2    United States           228000.0
# 3    United States          1551000.0
# 4    United States           181269.0
# ..             ...                ...
# 497  United States            51000.0
# 498  United States            39900.0
# 499  United States             8700.0
# 500  United States             5800.0
# 501  United States                NaN
#
#                                    Longbusinesssummary    Weight    matched
# 0    Apple Inc. designs, manufactures, and markets ...  0.069209       both
# 1    NVIDIA Corporation provides graphics and compu...  0.059350  left_only
# 2    Microsoft Corporation develops and supports so...  0.058401  left_only
# 3    Amazon.com, Inc. engages in the retail sale of...  0.042550  left_only
# 4    Alphabet Inc. offers various products and plat...  0.042309       both
# ..                                                 ...       ...        ...
# 497  Caesars Entertainment, Inc. operates as a gami...  0.000125       both
# 498  BorgWarner Inc., together with its subsidiarie...  0.000125  left_only
# 499  Qorvo, Inc. engages in development and commerc...  0.000120       both
# 500  FMC Corporation, an agricultural sciences comp...  0.000113       both
# 501  Amentum Holdings, Inc. provides engineering an...  0.000084       both
#
# [502 rows x 17 columns]

# %%
# Create indicator column for missing data
merged_data['missing'] = np.where(merged_data['matched'] == 'both', True, False)
merged_data.drop(columns=['matched'], inplace=True)

# Create a dataframe with missing data by sector
missing_by_sector = merged_data.groupby('Sector').agg({'missing': 'sum', 'Symbol': 'count'}).reset_index()
missing_by_sector['missing_percentage'] = (missing_by_sector['missing'] / missing_by_sector['Symbol']) * 100
missing_by_sector
# Out:
#                     Sector  missing  Symbol  missing_percentage
# 0          Basic Materials       15      22           68.181818
# 1   Communication Services       10      22           45.454545
# 2        Consumer Cyclical       37      55           67.272727
# 3       Consumer Defensive       25      37           67.567568
# 4                   Energy       17      22           77.272727
# 5       Financial Services       42      67           62.686567
# 6               Healthcare       41      62           66.129032
# 7              Industrials       43      70           61.428571
# 8              Real Estate       18      31           58.064516
# 9               Technology       59      82           71.951220
# 10               Utilities       23      32           71.875000

# %%
# Look at average missing percentage across sectors
average_missing_percentage = missing_by_sector['missing_percentage'].mean()
print(f"Average Missing Percentage Across Sectors: {average_missing_percentage:.2f}%")
# Out:
# Average Missing Percentage Across Sectors: 65.26%

# %%
# Create new stocks that only has companies with fully complete data
companies_all_missing_list = companies_all_missing.tolist()
companies_partially_missing_list = partially_missing.index.tolist()
companies_fully_complete_data = stocks.query('Symbol not in @companies_all_missing_list and Symbol not in @companies_partially_missing_list')
companies_fully_complete_data
# Out:
#                Date Symbol   Adj Close       Close        High         Low  \
# 3768     2010-01-04    AOS    5.937266    7.435000    7.480000    7.261667
# 3769     2010-01-05    AOS    5.861404    7.340000    7.431667    7.308333
# 3770     2010-01-06    AOS    5.864068    7.343333    7.405000    7.301667
# 3771     2010-01-07    AOS    5.881369    7.365000    7.425000    7.311667
# 3772     2010-01-08    AOS    5.967879    7.473333    7.485000    7.311667
# ...             ...    ...         ...         ...         ...         ...
# 1865155  2024-12-16    WTW  313.149994  313.149994  315.399994  310.989990
# 1865156  2024-12-17    WTW  310.529999  310.529999  311.850006  309.470001
# 1865157  2024-12-18    WTW  307.549988  307.549988  312.339996  307.209991
# 1865158  2024-12-19    WTW  311.000000  311.000000  312.450012  306.510010
# 1865159  2024-12-20    WTW  317.570007  317.570007  320.769989  310.350006
#
#                Open     Volume  Year
# 3768       7.295000  1104600.0  2010
# 3769       7.431667  1207200.0  2010
# 3770       7.335000   663000.0  2010
# 3771       7.356667   564000.0  2010
# 3772       7.331667   504600.0  2010
# ...             ...        ...   ...
# 1865155  313.040009   696800.0  2024
# 1865156  311.390015   887400.0  2024
# 1865157  309.660004   819700.0  2024
# 1865158  306.510010   767600.0  2024
# 1865159  313.290009  2033900.0  2024
#
# [565200 rows x 9 columns]

# %%
# Count unique companies with fully complete data
companies_fully_complete_data['Symbol'].nunique()
# Out:
# 150

# %%
# Join fully to metadata
companies_fully_complete_data = pd.merge(companies_fully_complete_data, company_metadata, on='Symbol', how='inner')
companies_fully_complete_data
# Out:
#               Date Symbol   Adj Close       Close        High         Low  \
# 0       2010-01-04    AOS    5.937266    7.435000    7.480000    7.261667
# 1       2010-01-05    AOS    5.861404    7.340000    7.431667    7.308333
# 2       2010-01-06    AOS    5.864068    7.343333    7.405000    7.301667
# 3       2010-01-07    AOS    5.881369    7.365000    7.425000    7.311667
# 4       2010-01-08    AOS    5.967879    7.473333    7.485000    7.311667
# ...            ...    ...         ...         ...         ...         ...
# 565195  2024-12-16    WTW  313.149994  313.149994  315.399994  310.989990
# 565196  2024-12-17    WTW  310.529999  310.529999  311.850006  309.470001
# 565197  2024-12-18    WTW  307.549988  307.549988  312.339996  307.209991
# 565198  2024-12-19    WTW  311.000000  311.000000  312.450012  306.510010
# 565199  2024-12-20    WTW  317.570007  317.570007  320.769989  310.350006
#
#               Open     Volume  Year Exchange  ... Currentprice    Marketcap  \
# 0         7.295000  1104600.0  2010      NYQ  ...        68.72   9964057600
# 1         7.431667  1207200.0  2010      NYQ  ...        68.72   9964057600
# 2         7.335000   663000.0  2010      NYQ  ...        68.72   9964057600
# 3         7.356667   564000.0  2010      NYQ  ...        68.72   9964057600
# 4         7.331667   504600.0  2010      NYQ  ...        68.72   9964057600
# ...            ...        ...   ...      ...  ...          ...          ...
# 565195  313.040009   696800.0  2024      NMS  ...       317.57  31987238912
# 565196  311.390015   887400.0  2024      NMS  ...       317.57  31987238912
# 565197  309.660004   819700.0  2024      NMS  ...       317.57  31987238912
# 565198  306.510010   767600.0  2024      NMS  ...       317.57  31987238912
# 565199  313.290009  2033900.0  2024      NMS  ...       317.57  31987238912
#
#               Ebitda Revenuegrowth       City  State         Country  \
# 0       8.091000e+08        -0.037  Milwaukee     WI   United States
# 1       8.091000e+08        -0.037  Milwaukee     WI   United States
# 2       8.091000e+08        -0.037  Milwaukee     WI   United States
# 3       8.091000e+08        -0.037  Milwaukee     WI   United States
# 4       8.091000e+08        -0.037  Milwaukee     WI   United States
# ...              ...           ...        ...    ...             ...
# 565195  2.581000e+09         0.057     London    NaN  United Kingdom
# 565196  2.581000e+09         0.057     London    NaN  United Kingdom
# 565197  2.581000e+09         0.057     London    NaN  United Kingdom
# 565198  2.581000e+09         0.057     London    NaN  United Kingdom
# 565199  2.581000e+09         0.057     London    NaN  United Kingdom
#
#         Fulltimeemployees                                Longbusinesssummary  \
# 0                 12000.0  A. O. Smith Corporation manufactures and marke...
# 1                 12000.0  A. O. Smith Corporation manufactures and marke...
# 2                 12000.0  A. O. Smith Corporation manufactures and marke...
# 3                 12000.0  A. O. Smith Corporation manufactures and marke...
# 4                 12000.0  A. O. Smith Corporation manufactures and marke...
# ...                   ...                                                ...
# 565195            48000.0  Willis Towers Watson Public Limited Company op...
# 565196            48000.0  Willis Towers Watson Public Limited Company op...
# 565197            48000.0  Willis Towers Watson Public Limited Company op...
# 565198            48000.0  Willis Towers Watson Public Limited Company op...
# 565199            48000.0  Willis Towers Watson Public Limited Company op...
#
#           Weight
# 0       0.000179
# 1       0.000179
# 2       0.000179
# 3       0.000179
# 4       0.000179
# ...          ...
# 565195  0.000575
# 565196  0.000575
# 565197  0.000575
# 565198  0.000575
# 565199  0.000575
#
# [565200 rows x 24 columns]

# %%
# Counts of Fully Complete Data by Sector
companies_fully_complete_data.groupby('Sector')['Symbol'].nunique()
# Out:
# Sector
# Basic Materials            7
# Communication Services     9
# Consumer Cyclical         16
# Consumer Defensive        12
# Energy                     5
# Financial Services        24
# Healthcare                17
# Industrials               22
# Real Estate               12
# Technology                17
# Utilities                  9
# Name: Symbol, dtype: int64

# %%
# Save cleaned data to csv
#companies_fully_complete_data.to_csv('cleaned_stocks_data.csv', index=False)
